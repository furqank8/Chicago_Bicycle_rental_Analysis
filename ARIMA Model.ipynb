# %%
# load required packages -----
library(stringr)
library(httr)
library(tidyverse)
library(lubridate)
library(dplyr)
library(rmarkdown)
library(knitr)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ forcats 0.5.2
# ✔ readr   2.1.3
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: timechange
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
install.packages("forecast")
library(forecast)
install.packages("xts")
library(xts)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘Rcpp’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’
#
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#
# Attaching package: ‘xts’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, last

# %%
library(cluster)    # clustering algorithms
install.packages("factoextra")
library(factoextra)
install.packages("geosphere")
library(geosphere)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘lazyeval’, ‘later’, ‘carData’, ‘pbkrtest’, ‘quantreg’, ‘lme4’, ‘htmlwidgets’, ‘crosstalk’, ‘promises’, ‘estimability’, ‘numDeriv’, ‘mvtnorm’, ‘corrplot’, ‘viridis’, ‘car’, ‘DT’, ‘ellipse’, ‘emmeans’, ‘flashClust’, ‘leaps’, ‘multcompView’, ‘scatterplot3d’, ‘ggsci’, ‘cowplot’, ‘ggsignif’, ‘gridExtra’, ‘polynom’, ‘rstatix’, ‘plyr’, ‘abind’, ‘dendextend’, ‘FactoMineR’, ‘ggpubr’, ‘reshape2’, ‘ggrepel’
#
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘sp’

# %%
divvy <- read_csv("bicycle_weather.csv")
# Out:
# Rows: 3667294 Columns: 17
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (6): rideable_type, start_station_name, end_station_name, member_casual...
# dbl  (8): start_lat, start_lng, end_lat, end_lng, ride_duration, year, month...
# dttm (2): started_at, ended_at
# date (1): start_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# str() to display the structure of bicycle_data
str(divvy)
# Out:
# spc_tbl_ [3,667,294 × 17] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ rideable_type     : chr [1:3667294] "docked_bike" "docked_bike" "docked_bike" "docked_bike" ...
#  $ started_at        : POSIXct[1:3667294], format: "2020-04-26 17:45:14" "2020-04-17 17:08:54" ...
#  $ ended_at          : POSIXct[1:3667294], format: "2020-04-26 18:12:03" "2020-04-17 17:17:03" ...
#  $ start_station_name: chr [1:3667294] "Eckhart Park" "Drake Ave & Fullerton Ave" "McClurg Ct & Erie St" "California Ave & Division St" ...
#  $ end_station_name  : chr [1:3667294] "Lincoln Ave & Diversey Pkwy" "Kosciuszko Park" "Indiana Ave & Roosevelt Rd" "Wood St & Augusta Blvd" ...
#  $ start_lat         : num [1:3667294] 41.9 41.9 41.9 41.9 41.9 ...
#  $ start_lng         : num [1:3667294] -87.7 -87.7 -87.6 -87.7 -87.6 ...
#  $ end_lat           : num [1:3667294] 41.9 41.9 41.9 41.9 42 ...
#  $ end_lng           : num [1:3667294] -87.7 -87.7 -87.6 -87.7 -87.7 ...
#  $ member_casual     : chr [1:3667294] "member" "member" "member" "member" ...
#  $ week_days         : chr [1:3667294] "Sunday" "Friday" "Wednesday" "Tuesday" ...
#  $ ride_duration     : num [1:3667294] 0.447 0.136 0.24 0.203 0.882 ...
#  $ start_date        : Date[1:3667294], format: "2020-04-26" "2020-04-17" ...
#  $ week              : chr [1:3667294] "weekend" "weekday" "weekday" "weekday" ...
#  $ year              : num [1:3667294] 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 ...
#  $ month             : num [1:3667294] 4 4 4 4 4 4 4 4 4 4 ...
#  $ day               : num [1:3667294] 26 17 1 7 18 30 2 7 15 4 ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   rideable_type = col_character(),
#   ..   started_at = col_datetime(format = ""),
#   ..   ended_at = col_datetime(format = ""),
#   ..   start_station_name = col_character(),
#   ..   end_station_name = col_character(),
#   ..   start_lat = col_double(),
#   ..   start_lng = col_double(),
#   ..   end_lat = col_double(),
#   ..   end_lng = col_double(),
#   ..   member_casual = col_character(),
#   ..   week_days = col_character(),
#   ..   ride_duration = col_double(),
#   ..   start_date = col_date(format = ""),
#   ..   week = col_character(),
#   ..   year = col_double(),
#   ..   month = col_double(),
#   ..   day = col_double()
#   .. )
#  - attr(*, "problems")=<externalptr>

# %%
# display column names and summary
colnames(divvy)
# Out:
#  [1] "rideable_type"      "started_at"         "ended_at"
#  [4] "start_station_name" "end_station_name"   "start_lat"
#  [7] "start_lng"          "end_lat"            "end_lng"
# [10] "member_casual"      "week_days"          "ride_duration"
# [13] "start_date"         "week"               "year"
# [16] "month"              "day"

# %%
summary(divvy)
# Out:
#  rideable_type        started_at
#  Length:3667294     Min.   :2020-04-01 00:00:30.00
#  Class :character   1st Qu.:2020-07-17 19:53:12.00
#  Mode  :character   Median :2020-09-04 00:42:46.50
#                     Mean   :2020-09-29 07:16:42.08
#                     3rd Qu.:2020-11-12 12:08:15.00
#                     Max.   :2021-05-31 23:53:35.00
#     ended_at                      start_station_name end_station_name
#  Min.   :2020-04-01 00:10:45.00   Length:3667294     Length:3667294
#  1st Qu.:2020-07-17 20:27:32.00   Class :character   Class :character
#  Median :2020-09-04 01:18:04.00   Mode  :character   Mode  :character
#  Mean   :2020-09-29 07:41:51.61
#  3rd Qu.:2020-11-12 12:24:54.25
#  Max.   :2021-06-08 13:37:43.00
#    start_lat       start_lng         end_lat         end_lng
#  Min.   :41.65   Min.   :-87.77   Min.   :41.65   Min.   :-87.77
#  1st Qu.:41.88   1st Qu.:-87.66   1st Qu.:41.88   1st Qu.:-87.66
#  Median :41.90   Median :-87.64   Median :41.90   Median :-87.64
#  Mean   :41.90   Mean   :-87.64   Mean   :41.91   Mean   :-87.64
#  3rd Qu.:41.93   3rd Qu.:-87.63   3rd Qu.:41.93   3rd Qu.:-87.63
#  Max.   :42.06   Max.   :-87.53   Max.   :42.07   Max.   :-87.53
#  member_casual       week_days         ride_duration         start_date
#  Length:3667294     Length:3667294     Min.   :-484.1661   Min.   :2020-04-01
#  Class :character   Class :character   1st Qu.:   0.1325   1st Qu.:2020-07-17
#  Mode  :character   Mode  :character   Median :   0.2422   Median :2020-09-04
#                                        Mean   :   0.4193   Mean   :2020-09-28
#                                        3rd Qu.:   0.4436   3rd Qu.:2020-11-12
#                                        Max.   : 978.6672   Max.   :2021-05-31
#      week                year          month            day
#  Length:3667294     Min.   :2020   Min.   : 1.00   Min.   : 1.00
#  Class :character   1st Qu.:2020   1st Qu.: 5.00   1st Qu.: 8.00
#  Mode  :character   Median :2020   Median : 7.00   Median :16.00
#                     Mean   :2020   Mean   : 7.14   Mean   :15.84
#                     3rd Qu.:2020   3rd Qu.: 9.00   3rd Qu.:24.00
#                     Max.   :2021   Max.   :12.00   Max.   :31.00

# %%
tail(divvy)
# Out:
#   rideable_type started_at          ended_at            start_station_name
# 1 classic_bike  2021-05-02 18:05:56 2021-05-02 18:22:03 Clark St & Lincoln Ave
# 2 classic_bike  2021-05-27 09:30:38 2021-05-27 09:44:36 Dayton St & North Ave
# 3 electric_bike 2021-05-03 15:06:58 2021-05-03 15:12:54 Clark St & Winnemac Ave
# 4 electric_bike 2021-05-01 12:55:40 2021-05-01 13:03:49 Clark St & Lincoln Ave
# 5 electric_bike 2021-05-14 18:45:02 2021-05-14 18:51:17 Clark St & Winnemac Ave
# 6 classic_bike  2021-05-01 01:20:34 2021-05-01 01:33:40 Clark St & Lincoln Ave
#   end_station_name             start_lat start_lng end_lat  end_lng
# 1 Stockton Dr & Wrightwood Ave 41.91569  -87.63460 41.93132 -87.63874
# 2 Winchester Ave & Elston Ave  41.91058  -87.64942 41.92409 -87.67646
# 3 Clark St & Montrose Ave      41.97332  -87.66770 41.96164 -87.66621
# 4 Stockton Dr & Wrightwood Ave 41.91574  -87.63464 41.93124 -87.63878
# 5 Clark St & Montrose Ave      41.97338  -87.66784 41.96163 -87.66616
# 6 Stockton Dr & Wrightwood Ave 41.91569  -87.63460 41.93132 -87.63874
#   member_casual week_days ride_duration start_date week    year month day
# 1 member        Sunday    0.26861111    2021-05-02 weekend 2021 5      2
# 2 member        Thursday  0.23277778    2021-05-27 weekday 2021 5     27
# 3 casual        Monday    0.09888889    2021-05-03 weekday 2021 5      3
# 4 casual        Saturday  0.13583333    2021-05-01 weekend 2021 5      1
# 5 casual        Friday    0.10416667    2021-05-14 weekday 2021 5     14
# 6 casual        Saturday  0.21833333    2021-05-01 weekend 2021 5      1

# %%
#gives type of bicycle_data
class(divvy)
# Out:
# [1] "spec_tbl_df" "tbl_df"      "tbl"         "data.frame"

# %%
sum(is.na(divvy))
# Out:
# [1] 0

# %% [markdown]
# 'rideable_type''started_at''ended_at''start_station_name''end_station_name''start_lat''start_lng''end_lat''end_lng''member_casual''week_days''ride_duration''start_date''week''year''month''day'

# %%
divvy <- divvy[divvy$start_station_name	!= '', ] 
divvy <- divvy[divvy$end_station_name	!= '', ]

# %%
## Find the number of check-outs per station
start_station_name <- unique(divvy$start_station_name)
head(start_station_name)

# ## Find the number of check-ins per station
end_station_name <- unique(divvy$end_station_name)
head(end_station_name)
# Out:
# [1] "Eckhart Park"                        "Drake Ave & Fullerton Ave"
# [3] "McClurg Ct & Erie St"                "California Ave & Division St"
# [5] "Rush St & Hubbard St"                "Mies van der Rohe Way & Chicago Ave"
# [1] "Lincoln Ave & Diversey Pkwy" "Kosciuszko Park"
# [3] "Indiana Ave & Roosevelt Rd"  "Wood St & Augusta Blvd"
# [5] "Sheridan Rd & Lawrence Ave"  "Streeter Dr & Grand Ave"

# %%
str(start_station_name)
str(end_station_name)
start_station_name[!(start_station_name %in% end_station_name)]
end_station_name[!(end_station_name %in% start_station_name)]
# Out:
#  chr [1:710] "Eckhart Park" "Drake Ave & Fullerton Ave" ...
#  chr [1:712] "Lincoln Ave & Diversey Pkwy" "Kosciuszko Park" ...
# [1] "hubbard_test_lws" "Altgeld Gardens"
# [1] "Avenue L & 114th St"
# [2] "N Damen Ave & W Wabansia St"
# [3] "N Clark St & W Elm St"
# [4] "Woodlawn & 103rd - Olive Harvey Vaccination Site"

# %%
# # Remove row based on condition
# divvy <- divvy[divvy$start_station_name	!= 'hubbard_test_lws', ] 
# divvy <- divvy[divvy$start_station_name	!= 'Altgeld Gardens', ] 
# divvy <- divvy[divvy$end_station_name	!= 'Avenue L & 114th St', ] 
# divvy <- divvy[divvy$end_station_name	!= 'N Damen Ave & W Wabansia St', ] 
# divvy <- divvy[divvy$end_station_name	!= 'N Clark St & W Elm St', ] 
# divvy <- divvy[divvy$end_station_name	!= 'Woodlawn & 103rd - Olive Harvey Vaccination Site', ] 
 
# start_station_name <- unique(divvy$start_station_name)
# end_station_name <- unique(divvy$end_station_name)

# str(start_station_name)
# str(end_station_name)
# Out:
#  chr [1:708] "Eckhart Park" "Drake Ave & Fullerton Ave" ...
#  chr [1:708] "Lincoln Ave & Diversey Pkwy" "Kosciuszko Park" ...

# %%
#Top 5 stations with most check outs
start_station_counts <- divvy %>% group_by(start_station_name) %>% summarise(n = n()) %>% ungroup() %>% arrange(desc(n))
head(start_station_counts, 5)
#Top 5 stations with least check outs
tail(start_station_counts, 200)
# Out:
#   start_station_name         n
# 1 Streeter Dr & Grand Ave    39923
# 2 Clark St & Elm St          36247
# 3 Lake Shore Dr & Monroe St  35007
# 4 Theater on the Lake        34500
# 5 Lake Shore Dr & North Blvd 30410
#     start_station_name                             n
# 1   Drake Ave & Addison St                         568
# 2   Ridge Blvd & Howard St                         568
# 3   Eberhart Ave & 61st St                         547
# 4   Austin Blvd & Lake St                          533
# 5   Kilbourn Ave & Irving Park Rd                  514
# 6   Fairfield Ave & Roosevelt Rd                   509
# 7   Knox Ave & Montrose Ave                        509
# 8   Central Park Ave & Ogden Ave                   496
# 9   Stony Island Ave & 64th St                     496
# 10  Sacramento Blvd & Franklin Blvd                484
# 11  Stony Island Ave & 71st St                     480
# 12  MLK Jr Dr & 56th St                            478
# 13  Austin Blvd & Madison St                       442
# 14  Rainbow Beach                                  433
# 15  Wolcott Ave & Fargo Ave                        428
# 16  State St & Pershing Rd                         427
# 17  Millard Ave & 26th St                          413
# 18  HUBBARD ST BIKE CHECKING (LBS-WH-TEST)         391
# 19  Albany Ave & 26th St                           390
# 20  Princeton Ave & 47th St                        367
# 21  Phillips Ave & 79th St                         356
# 22  Kedzie Ave & 21st St                           355
# 23  Stony Island Ave & 75th St                     354
# 24  Western Blvd & 48th Pl                         324
# 25  Wentworth Ave & Cermak Rd (Temp)               321
# 26  Yates Blvd & 75th St                           321
# 27  Austin Blvd & Chicago Ave                      319
# 28  MLK Jr Dr & 63rd St                            315
# 29  Western Ave & 28th St                          315
# 30  Cottage Grove Ave & 67th St                    304
# ⋮   ⋮                                              ⋮
# 171 Base - 2132 W Hubbard Warehouse                28
# 172 Carpenter St & 63rd St                         28
# 173 South Chicago Ave & Elliot Ave                 27
# 174 Torrence Ave & 106th St                        27
# 175 N Southport Ave & W Newport Ave                26
# 176 Western Ave & 111th St                         24
# 177 Elston Ave & Cortland St                       23
# 178 Michigan Ave & 114th St                        22
# 179 Vincennes Ave & 104th St                       22
# 180 Ada St & 113th St                              21
# 181 Eberhart Ave & 131st St                        21
# 182 Hegewisch Metra Station                        19
# 183 Halsted & 63rd - Kennedy-King Vaccination Site 18
# 184 Major Taylor Trail & 124th St                  18
# 185 Torrence Ave & 126th Pl                        16
# 186 W Washington Blvd & N Peoria St                16
# 187 Western Ave & 104th St                         16
# 188 Damen Ave & Walnut (Lake) St (*)               15
# 189 Jeffery Blvd & 91st St                         13
# 190 N Carpenter St & W Lake St                     13
# 191 N Paulina St & Lincoln Ave                     12
# 192 Kedzie Ave & 110th St                          11
# 193 Ashland Ave & 73rd St                           9
# 194 Loomis St & 89th St                             5
# 195 Commercial Ave & 100th St                       3
# 196 Eggleston Ave & 69th St (*)                     3
# 197 Hampden Ct & Diversey Ave                       2
# 198 Kedzie Ave & 104th St                           2
# 199 N Hampden Ct & W Diversey Ave                   1
# 200 Stewart Ave & 63rd St (*)                       1

# %%
#Top 5 stations with most check ins 
end_station_counts <- divvy %>% group_by(end_station_name) %>% summarise(n = n()) %>% ungroup() %>% arrange(desc(n))
head(end_station_counts, 5)
#Top 5 stations with least check ins 
tail(end_station_counts, 200)
# Out:
#   end_station_name           n
# 1 Streeter Dr & Grand Ave    42431
# 2 Theater on the Lake        35828
# 3 Clark St & Elm St          35090
# 4 Lake Shore Dr & Monroe St  34889
# 5 Lake Shore Dr & North Blvd 30491
#     end_station_name                                      n
# 1   Ridge Blvd & Touhy Ave                                560
# 2   Fairfield Ave & Roosevelt Rd                          553
# 3   Prairie Ave & Garfield Blvd                           550
# 4   Kilbourn Ave & Irving Park Rd                         546
# 5   Knox Ave & Montrose Ave                               541
# 6   Stony Island Ave & 71st St                            502
# 7   Sacramento Blvd & Franklin Blvd                       501
# 8   Drake Ave & Addison St                                500
# 9   Stony Island Ave & 64th St                            499
# 10  Ridge Blvd & Howard St                                488
# 11  Central Park Ave & Ogden Ave                          478
# 12  Millard Ave & 26th St                                 470
# 13  W Oakdale Ave & N Broadway                            470
# 14  MLK Jr Dr & 56th St                                   461
# 15  Rainbow Beach                                         435
# 16  Stony Island Ave & 75th St                            429
# 17  Western Blvd & 48th Pl                                424
# 18  Austin Blvd & Madison St                              423
# 19  Wood St & Chicago Ave (*)                             419
# 20  Wolcott Ave & Fargo Ave                               417
# 21  State St & Pershing Rd                                406
# 22  Albany Ave & 26th St                                  405
# 23  Leavitt St & Division St (*)                          401
# 24  Phillips Ave & 79th St                                365
# 25  Kedzie Ave & 21st St                                  353
# 26  Austin Blvd & Chicago Ave                             347
# 27  Wentworth Ave & Cermak Rd (Temp)                      342
# 28  Yates Blvd & 75th St                                  334
# 29  Kedzie Ave & Roosevelt Rd                             333
# 30  Central Park Blvd & 5th Ave                           326
# ⋮   ⋮                                                     ⋮
# 171 N Southport Ave & W Newport Ave                       30
# 172 Western Ave & 111th St                                28
# 173 State St & 123rd St                                   26
# 174 Carpenter St & 63rd St                                25
# 175 South Chicago Ave & Elliot Ave                        25
# 176 Hale Ave & 107th St                                   24
# 177 Eberhart Ave & 131st St                               21
# 178 Vincennes Ave & 104th St                              21
# 179 W Washington Blvd & N Peoria St                       21
# 180 Western & 28th - Velasquez Institute Vaccination Site 21
# 181 Elston Ave & Cortland St                              20
# 182 Torrence Ave & 106th St                               20
# 183 Ada St & 113th St                                     19
# 184 Racine Ave & 61st St                                  19
# 185 Western Ave & 104th St                                18
# 186 Hegewisch Metra Station                               17
# 187 N Paulina St & Lincoln Ave                            17
# 188 N Carpenter St & W Lake St                            16
# 189 Jeffery Blvd & 91st St                                14
# 190 Major Taylor Trail & 124th St                         13
# 191 Eggleston Ave & 69th St (*)                           12
# 192 Kedzie Ave & 110th St                                 12
# 193 Hampden Ct & Diversey Ave                              9
# 194 Ashland Ave & 73rd St                                  8
# 195 Loomis St & 89th St                                    5
# 196 Stewart Ave & 63rd St (*)                              5
# 197 Torrence Ave & 126th Pl                                5
# 198 Commercial Ave & 100th St                              4
# 199 Kedzie Ave & 104th St                                  1
# 200 N Hampden Ct & W Diversey Ave                          1

# %%
head(divvy,5)
# Out:
#   rideable_type started_at          ended_at
# 1 docked_bike   2020-04-26 17:45:14 2020-04-26 18:12:03
# 2 docked_bike   2020-04-17 17:08:54 2020-04-17 17:17:03
# 3 docked_bike   2020-04-01 17:54:13 2020-04-01 18:08:36
# 4 docked_bike   2020-04-07 12:50:19 2020-04-07 13:02:31
# 5 docked_bike   2020-04-18 10:22:59 2020-04-18 11:15:54
#   start_station_name           end_station_name            start_lat start_lng
# 1 Eckhart Park                 Lincoln Ave & Diversey Pkwy 41.8964   -87.6610
# 2 Drake Ave & Fullerton Ave    Kosciuszko Park             41.9244   -87.7154
# 3 McClurg Ct & Erie St         Indiana Ave & Roosevelt Rd  41.8945   -87.6179
# 4 California Ave & Division St Wood St & Augusta Blvd      41.9030   -87.6975
# 5 Rush St & Hubbard St         Sheridan Rd & Lawrence Ave  41.8902   -87.6262
#   end_lat end_lng  member_casual week_days ride_duration start_date week
# 1 41.9322 -87.6586 member        Sunday    0.4469444     2020-04-26 weekend
# 2 41.9306 -87.7238 member        Friday    0.1358333     2020-04-17 weekday
# 3 41.8679 -87.6230 member        Wednesday 0.2397222     2020-04-01 weekday
# 4 41.8992 -87.6722 member        Tuesday   0.2033333     2020-04-07 weekday
# 5 41.9695 -87.6547 casual        Saturday  0.8819444     2020-04-18 weekend
#   year month day
# 1 2020 4     26
# 2 2020 4     17
# 3 2020 4      1
# 4 2020 4      7
# 5 2020 4     18

# %%
## Find the number of unique days
unique_days <- unique(divvy$start_date)
head(unique_days)
str(unique_days)
# Out:
# [1] "2020-04-26" "2020-04-17" "2020-04-01" "2020-04-07" "2020-04-18"
# [6] "2020-04-30"
#  Date[1:424], format: "2020-04-26" "2020-04-17" "2020-04-01" "2020-04-07" "2020-04-18" ...

# %%
#total rented duration per day
duration_per_day <- divvy %>% group_by(start_date) %>% summarise(ride_duration = sum(ride_duration))%>% ungroup()
head(duration_per_day)
class(duration_per_day)
# Out:
#   start_date ride_duration
# 1 2020-04-01  771.1397
# 2 2020-04-02 2059.0081
# 3 2020-04-03 3990.6828
# 4 2020-04-04 1854.5689
# 5 2020-04-05 1352.2253
# 6 2020-04-06 1204.7522
# [1] "tbl_df"     "tbl"        "data.frame"

# %%
duration_per_day <- duration_per_day %>%
            filter(ride_duration > 0)

# %%
divvy_xts <- xts(duration_per_day$ride_duration, order.by = duration_per_day$start_date)
fig1 <- autoplot(divvy_xts) + ggtitle("Divvy daily ridership duration") + ylab("Hours per day") + xlab("Year")
fig1
# Out:
# plot without title

# %%
divvy_ts <- ts(divvy_xts, start = 2020, frequency = 365)
fig2 <- ggseasonplot(divvy_ts) + ggtitle("Seasonal plot of Divvy daily ridership")
fig2
# Out:
# plot without title

# %%
plot(divvy_xts['2020-05-01/2020-05-28'])
# Out:
# plot without title

# %%
divvy_w_ts <- ts(divvy_xts['2020-04-01/2021-03-31'], start = c(2020, 1), frequency = 7)
fig3 <- ggsubseriesplot(divvy_w_ts) + ggtitle("Subseries plot for weekly seasonality")
fig3
# Out:
# plot without title

# %%
divvy_w <- divvy %>% group_by(week = as.POSIXct(cut(start_date, "week"))) %>% summarise(weekly_rides = sum(ride_duration)) 
divvy_m <- divvy %>% group_by(month = as.POSIXct(cut(start_date, "month"))) %>% summarise(monthly_rides = sum(ride_duration))

# %%
divvy_d_test <- divvy_xts['2020-10-01/2021-03-31']
divvy_w_test <- divvy_w %>% filter(week >= "2020-10-01")
divvy_m_test <- divvy_m %>% filter(month >= "2020-10-01")

divvy_d_train <- divvy_xts['2020/2020-10-01']
divvy_w_train <- divvy_w %>% filter(week < "2020-10-01")
divvy_m_train <- divvy_m %>% filter(month < "2020-10-01")

divvy_m_train <- xts(divvy_m_train$monthly_rides, order.by = divvy_m_train$month)

# %%
d_ts <- ts(divvy_m_train, start = 2020, frequency = 12)
fit1 <- ets(d_ts, damped = TRUE)
summary(fit1)
# Out:
# Warning message in ets(d_ts, damped = TRUE):
# “Not enough data to use damping”
# ETS(A,A,N)
#
# Call:
#  ets(y = d_ts, damped = TRUE)
#
#   Smoothing parameters:
#     alpha = 0.0962
#     beta  = 1
#
#   Initial states:
#     l = 50221.5739
#     b = 59821.5944
#
#   sigma:  83414.45
# Training set error measures:
#                     ME     RMSE      MAE       MPE     MAPE MASE       ACF1
# Training set -34102.96 83414.45 66459.49 -37.54637 46.86938  NaN 0.08220422

# %%
fig4 <- autoplot(forecast(fit1, h = 6))
fig4
# Out:
# plot without title

# %%
?ets
fit1b <- ets(d_ts, model = c("AAA"), damped = TRUE)
summary(fit1b)
# Out:
# Warning message in ets(d_ts, model = c("AAA"), damped = TRUE):
# “Not enough data to use damping”
# ETS(A,A,N)
#
# Call:
#  ets(y = d_ts, model = c("AAA"), damped = TRUE)
#
#   Smoothing parameters:
#     alpha = 0.0962
#     beta  = 1
#
#   Initial states:
#     l = 50221.5739
#     b = 59821.5944
#
#   sigma:  83414.45
# Training set error measures:
#                     ME     RMSE      MAE       MPE     MAPE MASE       ACF1
# Training set -34102.96 83414.45 66459.49 -37.54637 46.86938  NaN 0.08220422

# %%
fc1 <- forecast(fit1b, h = 6)
plot(fc1, showgap = FALSE)
# Out:
# Plot with title “Forecasts from ETS(A,A,N)”

# %%
#arima
ggtsdisplay(divvy_m_train, main="Monthly Divvy Usage")
# Out:
# plot without title

# %%
ggtsdisplay(diff(divvy_m_train))
# Out:
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fit5 <- Arima(divvy_m_train, order = c(1,1,0), seasonal = list(order = c(0,1,0), period = 6))

fc5 <- forecast(fit5, h=3)
plot(fc5, showgap = FALSE)
# Out:
# Error in stats::arima(x = x, order = order, seasonal = seasonal, include.mean = include.mean, : too few non-missing observations
# Traceback:
#
# 1. Arima(divvy_m_train, order = c(1, 1, 0), seasonal = list(order = c(0,
#  .     1, 0), period = 6))
# 2. suppressWarnings(tmp <- stats::arima(x = x, order = order, seasonal = seasonal,
#  .     include.mean = include.mean, method = method, ...))
# 3. withCallingHandlers(expr, warning = function(w) if (inherits(w,
#  .     classes)) tryInvokeRestart("muffleWarning"))
# 4. stats::arima(x = x, order = order, seasonal = seasonal, include.mean = include.mean,
#  .     method = method, ...)
# 5. stop("too few non-missing observations")
